# %% [markdown]
# # Assignment 2: PBL Characteristics and landcover

# %% [markdown]
# #### Load necessary packages

# %%
#load necessary packages
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.axes
import pandas as pd
from pathlib import Path
import scipy.stats
from datetime import datetime
import datetime

# %% [markdown]
# #### Load data (US-MOz)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
group_number = 2
path_dir = Path.cwd() / 'data' / f'{group_number}'
# examine available files in your folder
list(path_dir.glob('*gz'))
# Out:
# [WindowsPath('C:/Users/fx000508/Documents/Assignment2/data/2/US-MMS_clean.csv.gz'),
#  WindowsPath('C:/Users/fx000508/Documents/Assignment2/data/2/US-MOz_clean.csv.gz')]

# %%
# specify the site name
name_of_site = 'US-MOz'

# %%
# load dataset
site_file = name_of_site + '_clean.csv.gz'
path_data = path_dir / site_file
df_dataM = pd.read_csv(path_data, index_col='time', parse_dates=['time'])
#df_data.head()

# %%
def DOY_to_datetime(row):
    year=int(row['modis_date'][1:5])
    DOY=int(row['modis_date'][5:])
    return datetime.datetime(year, 1, 1) + datetime.timedelta(DOY - 1)

df_LAIM=pd.read_csv('MODIS_LAI_AmeriFlux/statistics_Lai_500m-'+name_of_site+'.csv')
df_LAIM.columns=['product']+[i.split(' ')[1] for i in df_LAIM.columns if i!='product']
df_LAIM=df_LAIM.filter(['modis_date','value_mean'])


df_LAIM.set_index(df_LAIM.apply(DOY_to_datetime,axis=1),inplace=True)
df_LAIM.drop('modis_date',axis=1,inplace=True)
df_LAIM = df_LAIM.loc['2005 01 01':'2007 12 31']

# %%
fontsize=15
df_LAIM.plot(legend=False,figsize=(12,4),fontsize=fontsize)
plt.ylabel('LAI',fontsize=fontsize)
plt.xlabel('Time',fontsize=fontsize)
plt.title('US-MOz')
# Out:
# Text(0.5, 1.0, 'US-MOz')

# %% [markdown]
# #### Load data (US-Bo1)

# %%
group_number = 6
path_dir = Path.cwd() / 'data' / f'{group_number}'
# examine available files in your folder
list(path_dir.glob('*gz'))
# Out:
# [WindowsPath('C:/Users/fx000508/Documents/Assignment2/data/6/US-Bo1_clean.csv.gz'),
#  WindowsPath('C:/Users/fx000508/Documents/Assignment2/data/6/US-Br3_clean.csv.gz')]

# %%
# specify the site name
name_of_site = 'US-Bo1'

# %%
# load dataset
site_file = name_of_site + '_clean.csv.gz'
path_data = path_dir / site_file
df_dataB = pd.read_csv(path_data, index_col='time', parse_dates=['time'])
#df_data.head()

# %%
def DOY_to_datetime(row):
    year=int(row['modis_date'][1:5])
    DOY=int(row['modis_date'][5:])
    return datetime.datetime(year, 1, 1) + datetime.timedelta(DOY - 1)

df_LAIB=pd.read_csv('MODIS_LAI_AmeriFlux/statistics_Lai_500m-'+name_of_site+'.csv')
df_LAIB.columns=['product']+[i.split(' ')[1] for i in df_LAIB.columns if i!='product']
df_LAIB=df_LAIB.filter(['modis_date','value_mean'])


df_LAIB.set_index(df_LAIB.apply(DOY_to_datetime,axis=1),inplace=True)
df_LAIB.drop('modis_date',axis=1,inplace=True)
df_LAIB = df_LAIB.loc['2005 01 01':'2007 12 31']

# %%
fontsize=15
fig,ax=plt.subplots(1,1,figsize=(5,5))
df_LAIB.value_mean.plot(ax=ax,figsize=(12,4),fontsize=fontsize, color='black', label='US-Bo1')
ax.set_ylabel('LAI',fontsize=fontsize)
ax.set_xlabel('Time',fontsize=fontsize)
df_LAIM.value_mean.plot(color='red', label='US-MOz',ax=ax)
ax.legend(loc='best')

# %% [markdown]
# ### Select years to analyse

# %%
#Years to analyse
df_dataMuse = df_dataM.loc['2005 01 01':'2007 12 31']
df_dataBuse = df_dataB.loc['2005 01 01':'2007 12 31']
#Daytime
df_Mday = df_dataMuse[df_dataMuse['SWIN'] > 5] 
df_Bday = df_dataBuse[df_dataBuse['SWIN'] > 5]

# %% [markdown]
# #### Select variables

# %%
dataM = df_Mday.loc[:,['SWIN','LWIN','SWOUT','LWOUT','NETRAD', 'H','LE','USTAR','TA','RH','PA','WS','WD']].dropna()
dataB = df_Bday.loc[:,['SWIN','LWIN','SWOUT','LWOUT','NETRAD', 'H','LE','USTAR','TA','RH','PA','WS','WD']].dropna()

# %% [markdown]
# ### Determine albedo

# %% [markdown]
# $$
# {\alpha}=\frac{SW_{out}}{SW_{in}}
# $$

# %% [markdown]
# where $SW_{out}$ is the outgoing shortwave radiation (W m$^{-2}$), and $SW_{in}$ is the incoming shortwave radiation (W m$^{-2}$).

# %%
#Find average albedos using radiation data
#Summer
SWIN_M = dataM.SWIN
SWOUT_M = dataM.SWOUT
alb_M = SWOUT_M/SWIN_M
#Winter
SWIN_B = dataB.SWIN
SWOUT_B = dataB.SWOUT
alb_B = SWOUT_B/SWIN_B

# %%
albM_midday = alb_M[(alb_M.index.hour>=10)&(alb_M.index.hour<=14)&(alb_M.index.minute==0)]
albB_midday = alb_B[(alb_B.index.hour>=10)&(alb_B.index.hour<=14)&(alb_B.index.minute==0)]

# %%
print (np.nanmean(albM_midday))
print (np.nanmean(albB_midday))
# Out:
# 0.11633370051148706
# 0.2151766514961162

# %%
#Plot albedo in a time series with LAI
#Plot averaged year albedo with averaged year LAI

# %%
#Assume surface energy balance closure, to calculate a1 - fraction of energy storage at each site.

# %%
#Roughness length at each site

# %%
#Zero plane displacement height

# %%
#Surface resistance

# %%
#Stability analysis using Obukhov length
#Determine fraction of stable, unstable and neutral conditions at each site

# %%
#Partitioning of the surface energy balance components
